# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import pandas as pd
import matplotlib.pyplot as plt
import nltk
# %matplotlib inline
# NLTK VADER for sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer

finwiz_url = 'https://finviz.com/quote.ashx?t='

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Hanad\AppData\Roaming\nltk_data...
# True

# %%
news_tables = {}
tickers = ['AMZN', 'TSLA', 'GOOG']

for ticker in tickers:
    url = finwiz_url + ticker
    req = Request(url=url,headers={'user-agent': 'my-app/0.0.1'}) 
    response = urlopen(req)    
    # Read the contents of the file into 'html'
    html = BeautifulSoup(response)
    # Find 'news-table' in the Soup and load it into 'news_table'
    news_table = html.find(id='news-table')
    # Add the table to our dictionary
    news_tables[ticker] = news_table

# %%
# Read one single day of headlines for 'AMZN' 
amzn = news_tables['AMZN']
# Get all the table rows tagged in HTML with <tr> into 'amzn_tr'
amzn_tr = amzn.findAll('tr')

for i, table_row in enumerate(amzn_tr):
    # Read the text of the element 'a' into 'link_text'
    a_text = table_row.a.text
    # Read the text of the element 'td' into 'data_text'
    td_text = table_row.td.text
    # Print the contents of 'link_text' and 'data_text' 
    print(a_text)
    print(td_text)
    # Exit after printing 4 rows of data
    if i == 3:
        break
# Out:
# Oracle, Walmart Invest in TikTok to Gain Social Media Toehold
# Sep-19-20 09:56PM
# Oracle TikTok Investment Wins Trumps Blessing: Deal at a Glance
# 08:45PM
# Comcast Doesn't Care if You Want to Cut the Cord
# 02:00PM
# Would You View Ads for Cheaper Phone Service? AT&T Bets Yes
# 11:30AM

# %%
parsed_news = []

# Iterate through the news
for file_name, news_table in news_tables.items():
    # Iterate through all tr tags in 'news_table'
    for x in news_table.findAll('tr'):
        # read the text from each tr tag into text
        # get text from a only
        text = x.a.get_text() 
        # splite text in the td tag into a list 
        date_scrape = x.td.text.split()
        # if the length of 'date_scrape' is 1, load 'time' as the only element

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        # else load 'date' as the 1st element and 'time' as the second    
        else:
            date = date_scrape[0]
            time = date_scrape[1]
        # Extract the ticker from the file name, get the string up to the 1st '_'  
        ticker = file_name.split('_')[0]
        
        # Append ticker, date, time and headline as a list to the 'parsed_news' list
        parsed_news.append([ticker, date, time, text])
        
parsed_news
# Out:
# [['AMZN',
#   'Sep-19-20',
#   '09:56PM',
#   'Oracle, Walmart Invest in TikTok to Gain Social Media Toehold'],
#  ['AMZN',
#   'Sep-19-20',
#   '08:45PM',
#   'Oracle TikTok Investment Wins Trumps Blessing: Deal at a Glance'],
#  ['AMZN',
#   'Sep-19-20',
#   '02:00PM',
#   "Comcast Doesn't Care if You Want to Cut the Cord"],
#  ['AMZN',
#   'Sep-19-20',
#   '11:30AM',
#   'Would You View Ads for Cheaper Phone Service? AT&T Bets Yes'],
#  ['AMZN',
#   'Sep-19-20',
#   '11:05AM',
#   'Dow Jones Futures: Stock Market Rally Still Fighting, But Bears Landing The Punches; Apple, Amazon, Netflix Hammered; Tesla Battery Day, Nike Earnings Key'],
#  ['AMZN',
#   'Sep-19-20',
#   '11:00AM',
#   "There Are 130 Video Apps That Get Apple's Reduced Cut"],
#  ['AMZN',
#   'Sep-19-20',
#   '10:22AM',
#   'Walmart, Amazon among donors to QAnon-promoting lawmaker'],
#  ['AMZN', 'Sep-19-20', '10:07AM', "Kohl's Layoffs Signal Deeper Issues"],
#  ['AMZN',
#   'Sep-19-20',
#   '09:22AM',
#   'Stock market news live updates: Tech rout drags Nasdaq, S&P 500 to lowest in at least 6 weeks; Dow slides nearly 1%'],
#  ['AMZN', 'Sep-19-20', '09:22AM', 'Will Amazon Split Its Stock?'],
#  ['AMZN',
#   'Sep-19-20',
#   '08:32AM',
#   "You Don't Need a Stock Split to Buy Amazon, Even If You Don't Have $3,100"],
#  ['AMZN',
#   'Sep-19-20',
#   '08:11AM',
#   '3 Tech Stocks to Buy in the Market Correction'],
#  ['AMZN',
#   'Sep-19-20',
#   '06:42AM',
#   'These 2 Companies Will Win Big From a Second Stimulus Check'],
#  ['AMZN',
#   'Sep-19-20',
#   '06:31AM',
#   'Investing Lessons From Retail Stock Market Earnings Season'],
#  ['AMZN',
#   'Sep-18-20',
#   '06:17PM',
#   'Why Albertsons Is a Buy: More Meals at Home and the Stock Is Cheap'],
#  ['AMZN',
#   'Sep-18-20',
#   '06:15PM',
#   'Big Tech Weighs Too Much on the S&P 500. Feast on These Stocks Instead.'],
#  ['AMZN',
#   'Sep-18-20',
#   '05:47PM',
#   'Stock Markets Fall, but These 4 Winners Keep on Winning'],
#  ['AMZN',
#   'Sep-18-20',
#   '05:31PM',
#   "'Nasdaq whale' closes more large options trades"],
#  ['AMZN', 'Sep-18-20', '05:18PM', "Lowe's Initiative for Small Businesses"],
#  ['AMZN',
#   'Sep-18-20',
#   '04:44PM',
#   'US STOCKS-Wall St posts 3rd week of declines as tech slide drags on'],
#  ['AMZN',
#   'Sep-18-20',
#   '04:34PM',
#   'DoJ Charges Six People in Amazon Bribery Scheme'],
#  ['AMZN',
#   'Sep-18-20',
#   '04:25PM',
#   'Apple, Microsoft, FANG Stocks Downgraded Amid Tech Sell-Off'],
#  ['AMZN',
#   'Sep-18-20',
#   '04:25PM',
#   'Netflix Inc. stock outperforms competitors despite losses on the day'],
#  ['AMZN',
#   'Sep-18-20',
#   '04:25PM',
#   'Amazon.com Inc. stock falls Friday, underperforms market'],
#  ['AMZN',
#   'Sep-18-20',
#   '04:25PM',
#   '3M Co. stock falls Friday, underperforms market'],
#  ['AMZN', 'Sep-18-20', '04:14PM', 'Market Recap: Friday, September 18'],
#  ['AMZN',
#   'Sep-18-20',
#   '04:11PM',
#   'GLOBAL MARKETS-Equities sink on virus angst, Fed aftermath; gold, yen rise'],
#  ['AMZN',
#   'Sep-18-20',
#   '04:00PM',
#   'US STOCKS-Indexes end lower, Nasdaq, S&P 500 post 3rd week of declines'],
#  ['AMZN',
#   'Sep-18-20',
#   '03:40PM',
#   'Amazon Ex-Employee Charged by U.S. in Merchant Bribery Plot'],
#  ['AMZN',
#   'Sep-18-20',
#   '03:14PM',
#   'Amazons Zoox Gets Green Light for Robotaxi Tests in California'],
#  ['AMZN',
#   'Sep-18-20',
#   '03:13PM',
#   'Mega-cap tech stock selloff has the QQQs on track for biggest monthly drop since the financial crisis'],
#  ['AMZN',
#   'Sep-18-20',
#   '03:06PM',
#   'US STOCKS-Indexes drop more than 1% as tech sell-off continues'],
#  ['AMZN',
#   'Sep-18-20',
#   '03:05PM',
#   'GLOBAL MARKETS-Equities sink on virus angst, Fed aftermath; gold, yen rise'],
#  ['AMZN',
#   'Sep-18-20',
#   '02:57PM',
#   "Buffett's IPO Investment and Citigroup's Next CEO"],
#  ['AMZN',
#   'Sep-18-20',
#   '02:02PM',
#   'Now Is the Time to Invest Outside the U.S., Managers Say. Heres What Theyre Buying.'],
#  ['AMZN', 'Sep-18-20', '01:47PM', "World's Top 10 Internet Companies"],
#  ['AMZN',
#   'Sep-18-20',
#   '01:41PM',
#   'U.S. Justice Department indicts six with conspiracy to pay bribes to Amazon employees'],
#  ['AMZN', 'Sep-18-20', '01:40PM', 'Stocks slide amid quadruple witching day'],
#  ['AMZN',
#   'Sep-18-20',
#   '01:38PM',
#   'U.S. Justice Department indicts six with conspiracy to pay bribes to Amazon employees'],
#  ['AMZN',
#   'Sep-18-20',
#   '01:03PM',
#   'US STOCKS-Wall Street falls in choppy trading as tech sell-off resumes'],
#  ['AMZN',
#   'Sep-18-20',
#   '01:00PM',
#   'Amazon Looks Vulnerable to Further Declines'],
#  ['AMZN',
#   'Sep-18-20',
#   '12:17PM',
#   'GLOBAL MARKETS-Equities sink on virus angsts, Fed aftermath; gold, yen rise'],
#  ['AMZN',
#   'Sep-18-20',
#   '11:57AM',
#   "Snowflake CEO: 'I am the biggest bull on this country in every way'"],
#  ['AMZN',
#   'Sep-18-20',
#   '11:50AM',
#   'US STOCKS-Wall Street falls in choppy trading as tech sell-off resumes'],
#  ['AMZN', 'Sep-18-20', '10:30AM', 'Where Will Chewy Be in 10 Years?'],
#  ['AMZN',
#   'Sep-18-20',
#   '10:12AM',
#   'Ant-Backed Paytm Fires Back After Google Play Store Yanks App'],
#  ['AMZN', 'Sep-18-20', '09:40AM', '3 Top Stocks Under $20'],
#  ['AMZN',
#   'Sep-18-20',
#   '08:54AM',
#   'US STOCKS-Nasdaq futures rise as tech selloff calms'],
#  ['AMZN',
#   'Sep-18-20',
#   '08:30AM',
#   '1 E-Commerce Stock to Buy and 1 to Sell After Q2 2020 Earnings'],
#  ['AMZN',
#   'Sep-18-20',
#   '08:23AM',
#   'Should You Buy JFrog Stock After Its Post-IPO Leap?'],
#  ['AMZN',
#   'Sep-18-20',
#   '08:00AM',
#   'Top Fund Avoids Fads, Sticks To Leaders Like Apple'],
#  ['AMZN', 'Sep-18-20', '07:52AM', "Amazon's Putting Pressure on Spotify"],
#  ['AMZN',
#   'Sep-18-20',
#   '07:17AM',
#   'Did Warren Buffett Just Make $800 Million on the Snowflake IPO?'],
#  ['AMZN',
#   'Sep-18-20',
#   '06:52AM',
#   '2 Stocks to Buy Before a Coronavirus Vaccine Arrives'],
#  ['AMZN',
#   'Sep-18-20',
#   '06:04AM',
#   '3 Cheap Stocks You Can Buy and Hold for Decades'],
#  ['AMZN',
#   'Sep-18-20',
#   '05:32AM',
#   'Walmart Stock Is In Buy Zone As Dow Giant Steps Up Amazon Fight'],
#  ['AMZN',
#   'Sep-18-20',
#   '04:24AM',
#   'Uber Fills Long-Vacant CTO Position With Amazon Exec'],
#  ['AMZN',
#   'Sep-18-20',
#   '12:30AM',
#   'One-Stop Shop, Brand Awareness and Product Fit Driving Retail Sales'],
#  ['AMZN',
#   'Sep-17-20',
#   '11:02PM',
#   'Apple to launch first online store in India next week'],
#  ['AMZN',
#   'Sep-17-20',
#   '10:59PM',
#   'Apple to Begin Online Sales in India Ahead of Holiday Season'],
#  ['AMZN',
#   'Sep-17-20',
#   '09:18PM',
#   "U.N. food chief urges Bezos, other billionaires to step up to help world's starving"],
#  ['AMZN',
#   'Sep-17-20',
#   '05:06PM',
#   'S&P 500 Falls as Fed Fears, Unemployment Rattle Investors, Sending Amazon, Retail, Real Estate Stocks Down'],
#  ['AMZN',
#   'Sep-17-20',
#   '04:57PM',
#   'US STOCKS-Wall St falls as tech sells off again, jobless claims still high'],
#  ['AMZN',
#   'Sep-17-20',
#   '04:55PM',
#   'Amazon Climate Fund Backs Startup Led by Former Tesla Top Executive'],
#  ['AMZN', 'Sep-17-20', '04:25PM', 'Market Recap: Thursday, September 17'],
#  ['AMZN',
#   'Sep-17-20',
#   '04:25PM',
#   'Netflix Inc. stock falls Thursday, underperforms market'],
#  ['AMZN',
#   'Sep-17-20',
#   '04:25PM',
#   'Amazon.com Inc. stock underperforms Thursday when compared to competitors'],
#  ['AMZN',
#   'Sep-17-20',
#   '04:25PM',
#   '3M Co. stock outperforms competitors on strong trading day'],
#  ['AMZN',
#   'Sep-17-20',
#   '04:22PM',
#   'GLOBAL MARKETS-Stocks buckle, dollar slips as investors mull Fed action'],
#  ['AMZN',
#   'Sep-17-20',
#   '04:16PM',
#   'Stock market news live updates: Tech stocks drag Nasdaq to worst day in 5; Dow snaps 4-day win streak'],
#  ['AMZN',
#   'Sep-17-20',
#   '04:00PM',
#   'US STOCKS-Wall St falls as tech stocks sink again, jobless claims still high'],
#  ['AMZN',
#   'Sep-17-20',
#   '03:25PM',
#   "AVOD Is Starting to Take a Bite Out of Subscription Services Like Netflix and Disney's Hulu"],
#  ['AMZN',
#   'Sep-17-20',
#   '03:23PM',
#   'Dow Jones Slips As Rally Attempt Fails; This Snowflake Melts'],
#  ['AMZN',
#   'Sep-17-20',
#   '03:05PM',
#   'Stocks sink as investors weigh Fed, economic headwinds'],
#  ['AMZN',
#   'Sep-17-20',
#   '03:04PM',
#   'GLOBAL MARKETS-Stocks buckle, dollar slips as investors mull Fed action'],
#  ['AMZN',
#   'Sep-17-20',
#   '02:49PM',
#   'US STOCKS-Wall St sinks more than 1% as tech stocks resume slide'],
#  ['AMZN',
#   'Sep-17-20',
#   '02:15PM',
#   'Amazon Bets Big on Electric Revolution: Green Festival Update'],
#  ['AMZN',
#   'Sep-17-20',
#   '01:53PM',
#   "Apple's stock falls toward first close below 50-day moving average in 5 months"],
#  ['AMZN',
#   'Sep-17-20',
#   '01:45PM',
#   'This recycling giant just took a big step in the race to find the coffee cup of the future'],
#  ['AMZN',
#   'Sep-17-20',
#   '01:31PM',
#   "NVIDIA's High-Powered GeForce RTX 3080 Has Already Sold Out"],
#  ['AMZN',
#   'Sep-17-20',
#   '01:18PM',
#   'US STOCKS-Tech sell-off hits Wall St as jobless claims remain elevated'],
#  ['AMZN',
#   'Sep-17-20',
#   '12:46PM',
#   'Amazon Invests in Battery Recycler Founded by Former Tesla Exec'],
#  ['AMZN',
#   'Sep-17-20',
#   '12:40PM',
#   "TikTok deal will help Oracle 'catch up': analyst"],
#  ['AMZN',
#   'Sep-17-20',
#   '12:30PM',
#   'Forget Snowflake, Cloudera Is a Better Big Data Stock'],
#  ['AMZN', 'Sep-17-20', '12:10PM', '2 Stocks You Can Keep Forever'],
#  ['AMZN',
#   'Sep-17-20',
#   '11:56AM',
#   'CORRECTED-US STOCKS-Tech sell-off hits Wall St as jobless claims remain high'],
#  ['AMZN',
#   'Sep-17-20',
#   '11:19AM',
#   "Tesla's former executive is among first to win Amazon climate-fund investment"],
#  ['AMZN',
#   'Sep-17-20',
#   '11:17AM',
#   'GLOBAL MARKETS-Stocks buckle, dollar slips as investors mull Fed action'],
#  ['AMZN',
#   'Sep-17-20',
#   '10:51AM',
#   'Amazon Beats Walmart Again in Latest Showdown'],
#  ['AMZN',
#   'Sep-17-20',
#   '10:30AM',
#   '6 Ways Peloton Will Get to 100 Million Subscribers'],
#  ['AMZN',
#   'Sep-17-20',
#   '10:21AM',
#   'Are Robinhood Investors Right About These 2 Unstoppable Stocks?'],
#  ['AMZN',
#   'Sep-17-20',
#   '10:00AM',
#   'Forget Penny Stocks -- Amazon Is Better Protection Against Market Turmoil'],
#  ['AMZN',
#   'Sep-17-20',
#   '09:45AM',
#   "Amazon's Twitch Regains Its Top Star After Mixer's Collapse"],
#  ['AMZN',
#   'Sep-17-20',
#   '09:44AM',
#   "Read This Before Chasing Snowflake's Hot IPO"],
#  ['AMZN',
#   'Sep-17-20',
#   '09:42AM',
#   "Rivian, Redwood Materials among first recipients of Amazon's $2 billion climate fund"],
#  ['AMZN',
#   'Sep-17-20',
#   '09:38AM',
#   "Rivian, Redwood Materials among first recipients of Amazon's $2 bln climate fund"],
#  ['AMZN', 'Sep-17-20', '09:24AM', "Amazon's Gearing Up for a Massive Q4"],
#  ['AMZN',
#   'Sep-17-20',
#   '09:17AM',
#   "Amazon's first five climate fund investments include Tesla co-founder JB Straubel's startup Redwood Materials"],
#  ['AMZN', 'Sep-17-20', '08:29AM', '3 Recent IPOs to Add to Your Watchlist'],
#  ['AMZN',
#   'Sep-17-20',
#   '08:15AM',
#   'Dow Jones Futures Signal Key Test After Stock Market Rally Hits Resistance Following Fed Meeting'],
#  ['TSLA',
#   'Sep-19-20',
#   '09:58PM',
#   'Dow Jones Futures: Stock Market Rally Still Fighting, But Bears Landing The Punches; Trump Backs TikTok Deal, Tesla Battery Day Looms'],
#  ['TSLA',
#   'Sep-19-20',
#   '07:00PM',
#   'Goldman Sachs Made $100 Million Off Tesla Trades This Year'],
#  ['TSLA',
#   'Sep-19-20',
#   '08:32AM',
#   "You Don't Need a Stock Split to Buy Amazon, Even If You Don't Have $3,100"],
#  ['TSLA',
#   'Sep-19-20',
#   '07:30AM',
#   '3 Surprising Ways You Can Play the Electric-Vehicle Revolution'],
#  ['TSLA',
#   'Sep-19-20',
#   '02:53AM',
#   'Judge narrows Tesla lawsuit against former employee, dismisses defamation counterclaim'],
#  ['TSLA',
#   'Sep-18-20',
#   '11:09PM',
#   'What To Expect At Teslas Upcoming Battery Day'],
#  ['TSLA',
#   'Sep-18-20',
#   '08:21PM',
#   'Inside Saudi Arabias $360 Billion Investment Fund'],
#  ['TSLA',
#   'Sep-18-20',
#   '05:26PM',
#   'Teslas Big Battery Day Event: What to Expect'],
#  ['TSLA',
#   'Sep-18-20',
#   '04:34PM',
#   'Stocks Are Slipping Because Quadruple Witching Is Spooking the Market'],
#  ['TSLA',
#   'Sep-18-20',
#   '04:31PM',
#   'Nasdaq Falls 117 Points; Apple Stock Hit, But IPOs Unity Software, Compass Pathways Debut With Bullish Gains'],
#  ['TSLA',
#   'Sep-18-20',
#   '04:25PM',
#   'Tesla Inc. stock rises Friday, outperforms market'],
#  ['TSLA',
#   'Sep-18-20',
#   '04:20PM',
#   'Tesla Battery Day Will Be Mind Blowing. Heres What to Expect.'],
#  ['TSLA',
#   'Sep-18-20',
#   '04:20PM',
#   'Elon Musks Pay Helps Tesla Get a Record Price Target'],
#  ['TSLA',
#   'Sep-18-20',
#   '02:53PM',
#   'Stock-market benchmarks wipe out weekly gains amid Friday selloff but Tesla is a port in the storm'],
#  ['TSLA',
#   'Sep-18-20',
#   '02:15PM',
#   'Battery tech superstars JB Straubel of Redwood Materials, Celina Mikolajczak of Panasonic coming to TC Mobility 2020'],
#  ['TSLA',
#   'Sep-18-20',
#   '01:44PM',
#   'Dow Jones Sinks Nearly 400 Points; Tech-Heavy Nasdaq Leads Market Declines'],
#  ['TSLA',
#   'Sep-18-20',
#   '01:36PM',
#   'How Tesla Makes Money: all-electric cars and energy generation'],
#  ['TSLA',
#   'Sep-18-20',
#   '01:25PM',
#   'Why This Tesla Analyst Says Energy Will Become $200B Business For Automaker'],
#  ['TSLA',
#   'Sep-18-20',
#   '01:06PM',
#   "Nasdaq Weakness Can't Hold Tesla Back; Competition Hits Beyond Meat"],
#  ['TSLA',
#   'Sep-18-20',
#   '12:59PM',
#   'Cathie Woods Fund Bought More Tesla After Shares Got Slapped'],
#  ['TSLA', 'Sep-18-20', '12:52PM', "Expectations Rise for Tesla's Battery Day"],
#  ['TSLA',
#   'Sep-18-20',
#   '12:50PM',
#   'Dow Jones Extends Losses As Apple Drops; Nasdaq Falls Deeper In The Red'],
#  ['TSLA',
#   'Sep-18-20',
#   '12:09PM',
#   'Tesla (TSLA) Has Risen 823% in Last One Year, Outperforms Market'],
#  ['TSLA',
#   'Sep-18-20',
#   '11:57AM',
#   'Dow Jones Falls 150 Points, As Nasdaq Extends Losses; Tesla Snaps Back, While Beyond Meat Dives On Downgrade'],
#  ['TSLA',
#   'Sep-18-20',
#   '11:44AM',
#   'Tesla price target raised at Wedbush Securities ahead of battery day'],
#  ['TSLA',
#   'Sep-18-20',
#   '10:43AM',
#   'Tesla Analyst Raises Q3 Delivery Forecast On Robust Chinese Production, Demand Trajectory'],
#  ['TSLA',
#   'Sep-18-20',
#   '10:27AM',
#   'US STOCKS-Nasdaq inches higher after two-day tech slump'],
#  ['TSLA', 'Sep-18-20', '10:15AM', 'Unusual Options Activity Insight: Tesla'],
#  ['TSLA', 'Sep-18-20', '10:15AM', 'Why Tesla Stock Jumped 6% This Morning'],
#  ['TSLA',
#   'Sep-18-20',
#   '09:43AM',
#   'Dow Jones Today, Stocks Mixed After U.S. Sets Sunday Shutdown For TikTok'],
#  ['TSLA',
#   'Sep-18-20',
#   '09:43AM',
#   'Dow under pressure early Friday but S&P 500 and Nasdaq see muted gains to end the week'],
#  ['TSLA',
#   'Sep-18-20',
#   '09:42AM',
#   'Global Equities Mixed With Investors Cautious on Quadruple Witching Day'],
#  ['TSLA',
#   'Sep-18-20',
#   '08:54AM',
#   'US STOCKS-Nasdaq futures rise as tech selloff calms'],
#  ['TSLA',
#   'Sep-18-20',
#   '08:52AM',
#   'Tesla Stock Is Soaring, Beyond Meat Is Falling, and the Dow Is Barely Breaking Even'],
#  ['TSLA', 'Sep-18-20', '08:16AM', 'Are Electric Vehicle Stocks in a Bubble?'],
#  ['TSLA',
#   'Sep-18-20',
#   '08:14AM',
#   'Tesla stock gets a price target bump to $515 at Piper Sandler'],
#  ['TSLA', 'Sep-18-20', '07:08AM', "How Does Tesla's Debt Look?"],
#  ['TSLA',
#   'Sep-18-20',
#   '06:50AM',
#   'US STOCKS-Nasdaq futures bounce as tech selloff eases'],
#  ['TSLA',
#   'Sep-18-20',
#   '06:30AM',
#   "Tesla's stock bounces after Wedbush analyst boosts price target, but keeps rating at neutral"],
#  ['TSLA',
#   'Sep-18-20',
#   '04:59AM',
#   'Is Elon Musk The New Steve Jobs? Bill Gates Says No'],
#  ['TSLA',
#   'Sep-18-20',
#   '04:39AM',
#   'No Revenue Is No Problem in the 2020 Stock Market'],
#  ['TSLA',
#   'Sep-18-20',
#   '03:55AM',
#   'Volkswagen Has A Very Ambitious Production Target For Its Electric Vehicle Line'],
#  ['TSLA',
#   'Sep-18-20',
#   '02:30AM',
#   'Tesla wins case against former employee accused of hacking, transferring data'],
#  ['TSLA',
#   'Sep-18-20',
#   '02:10AM',
#   'Tesla wins case against former employee accused of hacking, transferring data'],
#  ['TSLA',
#   'Sep-17-20',
#   '09:18PM',
#   "U.N. food chief urges Bezos, other billionaires to step up to help world's starving"],
#  ['TSLA',
#   'Sep-17-20',
#   '06:02PM',
#   'Energy buyout firm Riverstone preparing cleantech SPAC IPO -sources'],
#  ['TSLA',
#   'Sep-17-20',
#   '05:48PM',
#   'Ford expanding Michigan factory for electric F-150'],
#  ['TSLA',
#   'Sep-17-20',
#   '04:32PM',
#   'MARKETS: Apple, Facebook, Tesla weigh on the Nasdaq  YF Premium is bullish on Lennar (LEN)'],
#  ['TSLA',
#   'Sep-17-20',
#   '04:25PM',
#   'Tesla Inc. stock underperforms Thursday when compared to competitors'],
#  ['TSLA',
#   'Sep-17-20',
#   '04:04PM',
#   'Canadian Driver Accused Of Using Tesla Autopilot While Sleeping'],
#  ['TSLA',
#   'Sep-17-20',
#   '03:39PM',
#   "Amazon Invests In Former Tesla CTO's Battery Recycling Startup"],
#  ['TSLA',
#   'Sep-17-20',
#   '02:37PM',
#   'GM Stock Revs Up As Ultium EV Future Takes Shape; Is It A Good Buy?'],
#  ['TSLA',
#   'Sep-17-20',
#   '02:27PM',
#   'Tesla Installs Battery Storage At Over 60 Electrify America Charging Sites'],
#  ['TSLA',
#   'Sep-17-20',
#   '01:48PM',
#   'Dow Jones Falls Over 250 Points; Apple, Tesla Slide'],
#  ['TSLA',
#   'Sep-17-20',
#   '01:39PM',
#   'Fidelitys $230 billion man explains why he dumped Tesla shares but still bets big on Warren Buffett'],
#  ['TSLA',
#   'Sep-17-20',
#   '01:18PM',
#   'US STOCKS-Tech sell-off hits Wall St as jobless claims remain elevated'],
#  ['TSLA',
#   'Sep-17-20',
#   '01:08PM',
#   'Dow Jones Slides 375 Points, As Nasdaq Sells Off; Apple, Tesla Tumble, While Snowflake Dives 15%'],
#  ['TSLA', 'Sep-17-20', '01:08PM', '3 things to know about Teslas battery day'],
#  ['TSLA',
#   'Sep-17-20',
#   '11:56AM',
#   'CORRECTED-US STOCKS-Tech sell-off hits Wall St as jobless claims remain high'],
#  ['TSLA',
#   'Sep-17-20',
#   '11:53AM',
#   'Option Dealers Pushed Prices to Extremes in Day Trader Onslaught'],
#  ['TSLA',
#   'Sep-17-20',
#   '11:06AM',
#   "Ford's Electric F-150 Coming In 2022, Over-The-Air Updates Planned"],
#  ['TSLA', 'Sep-17-20', '10:45AM', 'Why Tesla Stock Dropped 8% This Morning'],
#  ['TSLA',
#   'Sep-17-20',
#   '10:24AM',
#   'Tesla Stock Could Be Worth $100 Billion More Thanks to One Thing: Batteries'],
#  ['TSLA',
#   'Sep-17-20',
#   '09:42AM',
#   "Rivian, Redwood Materials among first recipients of Amazon's $2 billion climate fund"],
#  ['TSLA',
#   'Sep-17-20',
#   '08:04AM',
#   "Tesla's stock set to extend pullback, as volatility continues ahead of next week's Battery Day"],
#  ['TSLA',
#   'Sep-17-20',
#   '07:15AM',
#   "Is Tesla Stock A Buy Right Now? Here's What Earnings, Charts Show"],
#  ['TSLA',
#   'Sep-17-20',
#   '06:30AM',
#   'The 1999 Warren Buffett Quote That Should Terrify EV Investors'],
#  ['TSLA',
#   'Sep-17-20',
#   '05:51AM',
#   "3 Trends Robinhood Investors Can't Stop Buying Into"],
#  ['TSLA',
#   'Sep-17-20',
#   '05:37AM',
#   'Wall Street Opens Sharply Lower on Fed Gloom; Dow Down 350 Points'],
#  ['TSLA',
#   'Sep-17-20',
#   '05:23AM',
#   '2 Healthcare Stocks That Are Better Growth Buys Than Tesla'],
#  ['TSLA',
#   'Sep-17-20',
#   '01:09AM',
#   'The Musk Method: Learn from partners, then go it alone'],
#  ['TSLA',
#   'Sep-17-20',
#   '01:06AM',
#   'The Musk Method: Learn from partners then go it alone'],
#  ['TSLA',
#   'Sep-17-20',
#   '01:00AM',
#   'INSIGHT-The Musk Method: Learn from partners then go it alone'],
#  ['TSLA',
#   'Sep-16-20',
#   '11:28PM',
#   'LG Chem plans to separate battery business as electric cars take off'],
#  ['TSLA',
#   'Sep-16-20',
#   '11:15PM',
#   'LG Chem plans to separate battery business as electric cars take off'],
#  ['TSLA',
#   'Sep-16-20',
#   '05:45PM',
#   "In Snowflake's Wake, Unity Preps a Unique Debut"],
#  ['TSLA',
#   'Sep-16-20',
#   '04:31PM',
#   "How HVAC Could Become Tesla's Next Frontier After Auto, Solar"],
#  ['TSLA',
#   'Sep-16-20',
#   '04:25PM',
#   'Tesla Inc. stock underperforms Wednesday when compared to competitors'],
#  ['TSLA',
#   'Sep-16-20',
#   '04:11PM',
#   "GM's Electric Car Unit Eyes Self-Sufficiency Amid Spinoff Hopes"],
#  ['TSLA',
#   'Sep-16-20',
#   '02:33PM',
#   'GM Unveils More Electric-Vehicle Technology. Heres What That Means.'],
#  ['TSLA',
#   'Sep-16-20',
#   '01:39PM',
#   "Musk Says European Tesla Hardware 3 Retrofits 'Happening Soon'"],
#  ['TSLA',
#   'Sep-16-20',
#   '01:10PM',
#   "The Strange Timing Of NextEra's Stock Offering"],
#  ['TSLA',
#   'Sep-16-20',
#   '12:11PM',
#   'Dow Jones Rallies 200 Points On Coronavirus Treatment News Ahead Of Fed; FedEx Soars, While Nikola Dives'],
#  ['TSLA',
#   'Sep-16-20',
#   '10:59AM',
#   "Tesla Rebounds But It Didn't Escape Volatility"],
#  ['TSLA',
#   'Sep-16-20',
#   '09:57AM',
#   'Inspired by Apple or Tesla, e-bike company sets sights on an IPO as it brings in $40 million in venture capital funding'],
#  ['TSLA', 'Sep-16-20', '09:47AM', 'Why Nikola Stock Popped'],
#  ['TSLA',
#   'Sep-16-20',
#   '09:33AM',
#   "General Motors Shares Jump on 'Ultium' EV Drive System Plans, Tesla Slides"],
#  ['TSLA',
#   'Sep-16-20',
#   '09:02AM',
#   'Tesla and Apple Split Their Stocks. Now NextEra Energy Is Too.'],
#  ['TSLA',
#   'Sep-16-20',
#   '08:12AM',
#   'Dow Jones Futures Jump On Coronavirus Treatment News Ahead Of Fed Decision; Buffett-Backed Snowflake IPO To Debut'],
#  ['TSLA',
#   'Sep-16-20',
#   '08:02AM',
#   'Tesla gets a 33% price target boost but stock pulls back, in danger of snapping 5-day win streak'],
#  ['TSLA',
#   'Sep-16-20',
#   '06:58AM',
#   'US STOCKS-Futures rise on optimism around Fed; FedEx results shine'],
#  ['TSLA',
#   'Sep-16-20',
#   '06:19AM',
#   '3 Great Stocks With Better Growth Prospects Than Tesla to Buy'],
#  ['TSLA', 'Sep-15-20', '04:12PM', 'Tesla Stock Is Rising for a New Reason'],
#  ['TSLA',
#   'Sep-15-20',
#   '04:04PM',
#   'Can This Short-Term Options Trade In Tesla Generate A 255% Profit?'],
#  ['TSLA',
#   'Sep-15-20',
#   '04:03PM',
#   'Nikola Short Seller Piles On After Triggering SEC Probe'],
#  ['TSLA',
#   'Sep-15-20',
#   '03:14PM',
#   'Kolanovic Says Selloff Over With Market Past Impact From Options'],
#  ['TSLA',
#   'Sep-15-20',
#   '02:52PM',
#   "What Tesla App Downloads Say About EV Maker's Q3 Deliveries"],
#  ['TSLA',
#   'Sep-15-20',
#   '01:34PM',
#   'Nasdaq Soars 180 Points, Led By Tesla, Netflix, Qualcomm; Is A Big Quarter In Store For Adobe?'],
#  ['TSLA',
#   'Sep-15-20',
#   '12:58PM',
#   'US STOCKS-Wall Street climbs ahead of Apple event'],
#  ['TSLA',
#   'Sep-15-20',
#   '12:50PM',
#   'Tesla To Release Software Update To Fix 12v Battery Problems'],
#  ['GOOG',
#   'Sep-19-20',
#   '10:35PM',
#   'Trump Blesses Oracles TikTok Deal, Sets Up App Store Ban Delay'],
#  ['GOOG',
#   'Sep-19-20',
#   '09:56PM',
#   'Oracle, Walmart Invest in TikTok to Gain Social Media Toehold'],
#  ['GOOG',
#   'Sep-19-20',
#   '08:45PM',
#   'Oracle TikTok Investment Wins Trumps Blessing: Deal at a Glance'],
#  ['GOOG',
#   'Sep-19-20',
#   '07:48PM',
#   'TikTok App Store Ban Delayed After Trump Approves Oracle Deal'],
#  ['GOOG',
#   'Sep-19-20',
#   '09:22AM',
#   'Stock market news live updates: Tech rout drags Nasdaq, S&P 500 to lowest in at least 6 weeks; Dow slides nearly 1%'],
#  ['GOOG',
#   'Sep-19-20',
#   '07:33AM',
#   'With TikTok, Trump takes on 100 million more Americans'],
#  ['GOOG',
#   'Sep-18-20',
#   '11:37PM',
#   'Trump Backs Threats Against China With TikTok, WeChat Bans'],
#  ['GOOG',
#   'Sep-18-20',
#   '06:43PM',
#   'Why You Must Re-evaluate Your Portfolio Now'],
#  ['GOOG',
#   'Sep-18-20',
#   '06:43PM',
#   'Google Telehealth Partner Amwell Zooms 28% Higher in First Days of Trading'],
#  ['GOOG',
#   'Sep-18-20',
#   '06:16PM',
#   'S&P 500 Drops 33 Points as Mega-Tech Stocks Slide, Cruise Stocks Sink, and Investors Sell "Safe" Stocks Too'],
#  ['GOOG',
#   'Sep-18-20',
#   '06:15PM',
#   'Big Tech Weighs Too Much on the S&P 500. Feast on These Stocks Instead.'],
#  ['GOOG',
#   'Sep-18-20',
#   '05:20PM',
#   "Fmr. Pinterest President on social media addiction: 'We've got a really serious health issue on our hands'"],
#  ['GOOG',
#   'Sep-18-20',
#   '04:33PM',
#   "TikTok's abrupt end would send a 'chill to the boardroom': IMD Business prof"],
#  ['GOOG',
#   'Sep-18-20',
#   '04:30PM',
#   'Tech War Tensions Between U.S., China Elevate Over TikTok, WeChat Bans'],
#  ['GOOG',
#   'Sep-18-20',
#   '04:25PM',
#   'Apple, Microsoft, FANG Stocks Downgraded Amid Tech Sell-Off'],
#  ['GOOG',
#   'Sep-18-20',
#   '04:25PM',
#   'Apple Inc. stock underperforms Friday when compared to competitors'],
#  ['GOOG',
#   'Sep-18-20',
#   '04:25PM',
#   'Amazon.com Inc. stock falls Friday, underperforms market'],
#  ['GOOG',
#   'Sep-18-20',
#   '04:25PM',
#   'Alphabet Inc. Cl A stock falls Friday, underperforms market'],
#  ['GOOG', 'Sep-18-20', '04:14PM', 'Market Recap: Friday, September 18'],
#  ['GOOG',
#   'Sep-18-20',
#   '03:14PM',
#   'Amazons Zoox Gets Green Light for Robotaxi Tests in California'],
#  ['GOOG',
#   'Sep-18-20',
#   '02:57PM',
#   "Buffett's IPO Investment and Citigroup's Next CEO"],
#  ['GOOG', 'Sep-18-20', '01:47PM', "World's Top 10 Internet Companies"],
#  ['GOOG', 'Sep-18-20', '01:40PM', 'Stocks slide amid quadruple witching day'],
#  ['GOOG',
#   'Sep-18-20',
#   '01:07PM',
#   "Apple Fitness+ doesn't terrify the founder of this Peloton rival  here's why"],
#  ['GOOG',
#   'Sep-18-20',
#   '12:46PM',
#   "'They used my picture and I should've got paid for it'"],
#  ['GOOG',
#   'Sep-18-20',
#   '12:07PM',
#   'How long will the Silicon Valley employees who cant work from home keep getting paid?'],
#  ['GOOG',
#   'Sep-18-20',
#   '11:58AM',
#   'Google Restores Top India Payment App After One-Day Suspension'],
#  ['GOOG',
#   'Sep-18-20',
#   '11:57AM',
#   "Snowflake CEO: 'I am the biggest bull on this country in every way'"],
#  ['GOOG', 'Sep-18-20', '10:59AM', 'A Simple Technique to Profit From IPOs'],
#  ['GOOG',
#   'Sep-18-20',
#   '10:27AM',
#   'Trumps WeChat Ban Is Just a MAGA Wall in Cyberspace'],
#  ['GOOG',
#   'Sep-18-20',
#   '10:12AM',
#   'Ant-Backed Paytm Fires Back After Google Play Store Yanks App'],
#  ['GOOG',
#   'Sep-18-20',
#   '09:00AM',
#   'Big Firms Are (Finally) Boosting Child-Care Benefits'],
#  ['GOOG',
#   'Sep-18-20',
#   '08:53AM',
#   "Google Pulls India's Paytm App From Play Store"],
#  ['GOOG',
#   'Sep-18-20',
#   '08:01AM',
#   'Commerce Dept. issues order prohibiting WeChat, TikTok dealings'],
#  ['GOOG',
#   'Sep-18-20',
#   '07:47AM',
#   "Reports of Google Fiber's Death Are Greatly Exaggerated"],
#  ['GOOG',
#   'Sep-18-20',
#   '06:32AM',
#   "India's Paytm app back on Google store after removal over policy violations"],
#  ['GOOG',
#   'Sep-18-20',
#   '04:42AM',
#   "Google pulls India's Paytm app from Play Store for repeat policy violations"],
#  ['GOOG',
#   'Sep-18-20',
#   '03:59AM',
#   'TikTok Owner Is Gaining Confidence Beijing to Okay U.S. Deal'],
#  ['GOOG',
#   'Sep-18-20',
#   '02:34AM',
#   'TikTok and Instagram Face Off for Luxury Influencers'],
#  ['GOOG',
#   'Sep-17-20',
#   '05:15PM',
#   'Google-Backed American Well Stock Rises 28% in Market Debut'],
#  ['GOOG',
#   'Sep-17-20',
#   '04:25PM',
#   'Apple Inc. stock falls Thursday, underperforms market'],
#  ['GOOG',
#   'Sep-17-20',
#   '04:25PM',
#   'Amazon.com Inc. stock underperforms Thursday when compared to competitors'],
#  ['GOOG',
#   'Sep-17-20',
#   '04:25PM',
#   'Alphabet Inc. Cl A stock falls Thursday, underperforms market'],
#  ['GOOG',
#   'Sep-17-20',
#   '03:38PM',
#   'The race to build facial recognition tech for Africa is being led by this award-winning engineer'],
#  ['GOOG',
#   'Sep-17-20',
#   '03:34PM',
#   'Alphabet CFO Beats Back-to-Office Drum, Citing Tie to Innovation'],
#  ['GOOG',
#   'Sep-17-20',
#   '03:05PM',
#   'Stocks sink as investors weigh Fed, economic headwinds'],
#  ['GOOG',
#   'Sep-17-20',
#   '02:28PM',
#   "Google-backed 'plumber' Amwell spikes in debut, IPO a barometer of booming telehealth market"],
#  ['GOOG',
#   'Sep-17-20',
#   '01:53PM',
#   "Apple's stock falls toward first close below 50-day moving average in 5 months"],
#  ['GOOG',
#   'Sep-17-20',
#   '12:40PM',
#   "TikTok deal will help Oracle 'catch up': analyst"],
#  ['GOOG',
#   'Sep-17-20',
#   '12:30PM',
#   'Forget Snowflake, Cloudera Is a Better Big Data Stock'],
#  ['GOOG',
#   'Sep-17-20',
#   '11:24AM',
#   'A Deep Dive Into ZoomInfo -- the Other Cool "Zoom" Company'],
#  ['GOOG',
#   'Sep-17-20',
#   '09:44AM',
#   "Read This Before Chasing Snowflake's Hot IPO"],
#  ['GOOG',
#   'Sep-17-20',
#   '08:15AM',
#   'Is Google Stock A Buy? As DOJ Case Looms, Advertising, Cloud Outlook Key'],
#  ['GOOG',
#   'Sep-17-20',
#   '07:30AM',
#   'Is Salesforce Stock A Buy As Coronavirus Impacts Technology Budgets?'],
#  ['GOOG',
#   'Sep-17-20',
#   '06:00AM',
#   'Why Jay Shetty says this is the biggest mistake you can make'],
#  ['GOOG', 'Sep-17-20', '06:00AM', 'Influencers with Andy Serwer: Jay Shetty'],
#  ['GOOG',
#   'Sep-17-20',
#   '05:13AM',
#   'DOJ Indicts Chinese Hackers for Break-Ins at 100 Companies'],
#  ['GOOG',
#   'Sep-17-20',
#   '04:09AM',
#   'Facebook, Ray-Ban Team Up in Push to Make Smart Glasses Cool'],
#  ['GOOG',
#   'Sep-17-20',
#   '12:58AM',
#   "'It's their call': Australia regulator dares Facebook to block news content"],
#  ['GOOG',
#   'Sep-16-20',
#   '07:00PM',
#   'Google-Backed Amwell Starts Trading Today. What You Need to Know.'],
#  ['GOOG',
#   'Sep-16-20',
#   '06:00PM',
#   'Google Unveils New Search Updates to Help Local Shopping'],
#  ['GOOG',
#   'Sep-16-20',
#   '04:33PM',
#   'How the biggest stocks from 2000 performed in subsequent years'],
#  ['GOOG',
#   'Sep-16-20',
#   '04:25PM',
#   'Apple Inc. stock underperforms Wednesday when compared to competitors'],
#  ['GOOG',
#   'Sep-16-20',
#   '04:25PM',
#   'Amazon.com Inc. stock falls Wednesday, underperforms market'],
#  ['GOOG',
#   'Sep-16-20',
#   '04:25PM',
#   'Alphabet Inc. Cl A stock outperforms competitors despite losses on the day'],
#  ['GOOG', 'Sep-16-20', '03:52PM', 'Trump Nears Decision on Oracle-TikTok Bid'],
#  ['GOOG',
#   'Sep-16-20',
#   '03:40PM',
#   'Microsoft lost its best chance to be the cool tech company'],
#  ['GOOG',
#   'Sep-16-20',
#   '02:23PM',
#   'Luther.AI is a new AI tool that acts like Google for personal conversations'],
#  ['GOOG',
#   'Sep-16-20',
#   '12:43PM',
#   '$1 million every minute and more than 8 hours each day? The internet is mindboggling'],
#  ['GOOG',
#   'Sep-16-20',
#   '10:56AM',
#   'Amazon Steps Up Its Game to Counter This Growing Threat in India'],
#  ['GOOG',
#   'Sep-16-20',
#   '10:53AM',
#   'After $9 Billion in Fines, EU Says Something Nice About Google'],
#  ['GOOG',
#   'Sep-16-20',
#   '09:30AM',
#   'Google Is Getting Into Video-Calling Hardware'],
#  ['GOOG',
#   'Sep-16-20',
#   '08:58AM',
#   'Unity to Use IPO to Move Past Games to Real-World Challenges'],
#  ['GOOG',
#   'Sep-16-20',
#   '08:48AM',
#   "Apple Could Cripple Microsoft's and Google's iOS Cloud Gaming Apps"],
#  ['GOOG',
#   'Sep-16-20',
#   '06:00AM',
#   'Successful people have these things in common'],
#  ['GOOG',
#   'Sep-16-20',
#   '05:46AM',
#   'This is the most crowded trade of all-time: Morning Brief'],
#  ['GOOG',
#   'Sep-16-20',
#   '04:35AM',
#   'SoftBank, Naver to Take Line Private Through Squeeze Out'],
#  ['GOOG',
#   'Sep-15-20',
#   '09:27PM',
#   'FTC Prepares Possible Antitrust Lawsuit Against Facebook, Source Says'],
#  ['GOOG',
#   'Sep-15-20',
#   '08:26PM',
#   "Alphabet's Google Targets Carbon-Free Operation by 2030"],
#  ['GOOG',
#   'Sep-15-20',
#   '05:49PM',
#   'The Dow Went Nowhere Because Tuesday Was for Tech Stocks'],
#  ['GOOG',
#   'Sep-15-20',
#   '05:33PM',
#   'Senators Call Google Monopoly Upon Monopoly as DOJ Case Nears'],
#  ['GOOG',
#   'Sep-15-20',
#   '01:50PM',
#   'Apple to launch Apple Fitness+ service for $9.99 per month'],
#  ['GOOG',
#   'Sep-15-20',
#   '01:32PM',
#   'Apple debuts $399 Apple Watch Series 6 and $279 Apple Watch SE'],
#  ['GOOG',
#   'Sep-15-20',
#   '01:30PM',
#   'Apple Adds Blood Oxygen Sensor to Watch, Debuts Cheaper SE Model'],
#  ['GOOG',
#   'Sep-15-20',
#   '01:15PM',
#   'Microsoft Xbox Cloud Gaming Launches Today With More than 150 Games'],
#  ['GOOG',
#   'Sep-15-20',
#   '01:00PM',
#   'Google Sets Aggressive Carbon Reduction Target For 2030'],
#  ['GOOG',
#   'Sep-15-20',
#   '12:50PM',
#   'Nvidia Deal Threatens Arms Role as the Switzerland of Chips'],
#  ['GOOG',
#   'Sep-15-20',
#   '12:05PM',
#   'Dow Ends Flat as Financials Wobble Ahead of Fed; Tech Advances'],
#  ['GOOG',
#   'Sep-15-20',
#   '12:00PM',
#   'Google launches new AI-powered meeting room hardware'],
#  ['GOOG',
#   'Sep-15-20',
#   '11:56AM',
#   'Waze gets smarter with trip suggestions, lane guidance, traffic notifications and more'],
#  ['GOOG', 'Sep-15-20', '11:13AM', 'How to switch from Android to iPhone'],
#  ['GOOG',
#   'Sep-15-20',
#   '10:49AM',
#   'Vanguard faults Alphabet on CEO pay, names new proxy chief'],
#  ['GOOG',
#   'Sep-15-20',
#   '07:58AM',
#   "Some of the world's biggest investors are 'paranoid' about tech stocks getting pounded: survey"],
#  ['GOOG',
#   'Sep-15-20',
#   '07:00AM',
#   'What Are FANG Stocks, And Should You Invest In Them?'],
#  ['GOOG',
#   'Sep-15-20',
#   '06:03AM',
#   'Google faces grilling on ad business before U.S. Senate antitrust panel'],
#  ['GOOG',
#   'Sep-15-20',
#   '06:00AM',
#   'Snowflake Gives Investors a Rare Opportunity to Disrupt Amazon'],
#  ['GOOG',
#   'Sep-15-20',
#   '03:16AM',
#   "Amazon's Big Bet To Lure Indians To Alexa: Bollywood Megastar Amitabh Bachchan"],
#  ['GOOG',
#   'Sep-15-20',
#   '01:12AM',
#   'Bollywood Star\xa0Amitabh\xa0Bachchan Is the New Voice of Amazons\xa0Alexa'],
#  ['GOOG',
#   'Sep-14-20',
#   '09:37PM',
#   'TRAI says no to regulations for OTT players'],
#  ['GOOG',
#   'Sep-14-20',
#   '06:29PM',
#   "Google faces $3.2 billion lawsuit over use of children's data in U.K."]]

# %%
# Instantiate the sentiment intensity analyzer
vader = SentimentIntensityAnalyzer()

# Set column names
columns = ['ticker', 'date', 'time', 'headline']

# Convert the parsed_news list into a DataFrame called 'parsed_and_scored_news'
parsed_and_scored_news = pd.DataFrame(parsed_news, columns=columns)

# Iterate through the headlines and get the polarity scores using vader
scores = parsed_and_scored_news['headline'].apply(vader.polarity_scores).tolist()

# Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)

# Join the DataFrames of the news and the list of dicts
parsed_and_scored_news = parsed_and_scored_news.join(scores_df, rsuffix='_right')

# Convert the date column from string to datetime
parsed_and_scored_news['date'] = pd.to_datetime(parsed_and_scored_news.date).dt.date

parsed_and_scored_news.head()
# Out:
#   ticker        date     time  \
# 0   AMZN  2020-09-19  09:56PM
# 1   AMZN  2020-09-19  08:45PM
# 2   AMZN  2020-09-19  02:00PM
# 3   AMZN  2020-09-19  11:30AM
# 4   AMZN  2020-09-19  11:05AM
#
#                                             headline    neg    neu    pos  \
# 0  Oracle, Walmart Invest in TikTok to Gain Socia...  0.000  0.726  0.274
# 1  Oracle TikTok Investment Wins Trumps Blessing:...  0.000  0.504  0.496
# 2   Comcast Doesn't Care if You Want to Cut the Cord  0.363  0.537  0.100
# 3  Would You View Ads for Cheaper Phone Service? ...  0.000  0.787  0.213
# 4  Dow Jones Futures: Stock Market Rally Still Fi...  0.099  0.833  0.067
#
#    compound
# 0    0.5267
# 1    0.7845
# 2   -0.5312
# 3    0.4019
# 4   -0.2023

# %%
plt.rcParams['figure.figsize'] = [10, 6]

# Group by date and ticker columns from scored_news and calculate the mean
mean_scores = parsed_and_scored_news.groupby(['ticker','date']).mean()

# Unstack the column ticker
mean_scores = mean_scores.unstack()

# Get the cross-section of compound in the 'columns' axis
mean_scores = mean_scores.xs('compound', axis="columns").transpose()

# Plot a bar chart with pandas
mean_scores.plot(kind = 'bar')
plt.grid()
